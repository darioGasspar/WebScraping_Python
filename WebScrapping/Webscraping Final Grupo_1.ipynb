# %% [markdown]
# <center> <h1>Universidad Nacional de San Agustín de Arequipa</h1> </center>
# <center> <h1>Escuela Profesional de Ingeniería de Telecomunicaciones</h1> </center>
#
# <center> <h1> </h1> </center>
#
# <center><img src="https://user-images.githubusercontent.com/19308295/115939517-f1c6fe80-a463-11eb-989c-812ab4942586.png" width="380" height="4200"></center>

# %% [markdown]
# <center> <h2>Ingeniero Renzo Bolivar - Docente DAIE</h2> </center>

# %% [markdown]
# <center> <h1>Curso : Computación 2</h1> </center>

# %% [markdown]
# <center> <h1> GRUPO: 1 </h1> </center>

# %% [markdown]
# <center> <h2>INTEGRANTES:</h2> </center>
#
# <center> <h2>Apaza Valdivia, Leonel Saul</h2> </center>
#
# <center> <h2>Flores Mallma, Elmer Matias</h2> </center>
#
# <center> <h2>Gaspar Condorchoa, Ruben Dario</h2> </center>
#
# <center> <h2>Ramos Rodrigo, Franklin Harold</h2> </center>
#
# <center> <h2>Tello Alegria, Ronald Augusto</h2> </center>
#
# <center> <h2>Valero Arizabal, Kusi Lucero</h2> </center>

# %% [markdown]
# ![linea 1](https://user-images.githubusercontent.com/19308295/115926252-2b8a0c00-a448-11eb-9d9c-b43beaf0ff68.png)

# %% [markdown]
# <center> <h1> Investigación Web Scraping </h1> </center>

# %% [markdown]
# ## ¿Qué es WebScraping?

# %% [markdown]
# El web scraping se refiere al proceso de extracción de contenidos y datos de sitios web mediante software. Por ejemplo, la mayoría de los servicios de comparación de precios utilizan web scrapers para leer la información de precios de varias tiendas online. Es un proceso dentro del Data Science que se utiliza para la extracción de datos de sitios web, normalmente en el lenguaje de programación Python y mediante machine learning, simulando cómo navegaría un ser humano en determinadas páginas web. Se Extrae los datos de un sitio web con Python implica inspeccionar la página de la URL de destino, identificar los datos que desea extraer, escribir y ejecutar el código de extracción de datos y, por último, almacenar los datos en el formato deseado.

# %% [markdown]
# ## ¿Para Qué Se Utiliza el Web Scraping?

# %% [markdown]
# El web scraping se utiliza para extraer datos de páginas web de manera automatizada. Consiste en el proceso de recopilar información de manera estructurada desde diferentes sitios web, analizando el código HTML de las páginas y extrayendo los datos relevantes. Estos datos pueden incluir texto, imágenes, tablas, enlaces y otra información disponible en la página.
#
#
# El web scraping es una técnica muy útil en diversas situaciones. Algunos casos comunes de uso incluyen:
#
# - Extracción de datos: Permite recopilar grandes cantidades de información de diferentes fuentes en un formato estructurado. Esto puede ser útil para análisis de mercado, investigación competitiva, seguimiento de precios, recopilación de datos para estudios científicos, entre otros.
# - Monitoreo y seguimiento de sitios web: El scraping se puede utilizar para rastrear cambios en sitios web específicos, como actualizaciones de precios, noticias o disponibilidad de productos. Esto puede ser útil para tomar decisiones comerciales, mantenerse actualizado con la competencia o recibir alertas sobre eventos importantes.
# - Agregación de contenido: Permite recopilar contenido de múltiples fuentes y combinarlo en un solo lugar. Esto se utiliza en la creación de agregadores de noticias, directorios de empresas, comparadores de precios y otros sitios web que necesitan información actualizada proveniente de diferentes fuentes.
# - Análisis de datos: Los datos extraídos mediante web scraping se pueden utilizar para realizar análisis y obtener información útil. Esto incluye técnicas como el análisis de sentimientos en comentarios de clientes, el análisis de tendencias en redes sociales o la extracción de datos para entrenar modelos de aprendizaje automático.

# %% [markdown]
# ## ¿Cómo Funciona el Scraping Web?

# %% [markdown]
# El funcionamiento de Web Scraping consiste en una simulación de la navegación, que una persona realizaría, ya sea implementado a bajo nivel, como en HTTP (Hypertext Transfer Protocol), o incluido en ciertos navegadores web. Ésta simulación se realiza mediante programas denominados “bots”, que crean una clonación del cliqueo, la lectura y el “copy-paste”, automatizando la tarea de búsqueda y de recolección de datos. De modo que, Web Scraping se centra en la transformación del contenido no estructurado, por lo general en formato HTML, en datos estructurados que pueden ser almacenados y analizados.

# %% [markdown]
# ## Web scraping con Python

# %% [markdown]
# Fundamentalmente, por ser un lenguaje intuitivo, fácil de usar y por las librerías y herramientas que han surgido en torno al mismo para llevar a cabo esta técnica.
# Yo, en función del proyecto y sus características, normalmente sigo una de estas dos alternativas:
# * Utilizar las librerías requests y Beautiful Soup de manera conjunta
# * Utilizar el framework Scrapy. Este framework, además de hacer scraping (extraer información de una página) permite hacer crawling fácilmente (descubrir los enlaces de una web y navegar a través de ellos).
#
#
# #### Extrae datos y conviértelos
# Trabajamos con una amplia variedad de fuentes de datos sin procesar como bases de datos, hojas de cálculo, CSV, .pdf o sitios web.
#
# #### Localización
# Los datos que buscas pueden estar divididos en diferentes bases de datos o también se pueden ocultar detrás de un motor de búsqueda construido en un sitio web. Esto hace que la extracción sea una tarea compleja y prolongada en el tiempo
#
# #### Extracción
# Creamos scripts personalizados para tu proyecto con los que extraemos la información de forma ágil y sistemática sistemática . Aceleramos el proceso de recopilación de datos, reducimos el error humano al mínimo y detectamos y resolvemos problemas en tiempo real.
#
# #### Procesamiento
# Una vez que tenemos el conjunto de datos podemos fusionar dos bases de datos en una, aplicar filtros específicos o reorganizar la estructura. Esto es particularmente útil cuando se utilizan herramientas estadísticas para analizar los datos extraidos.

# %% [markdown]
# ## Ética, copyright y fair use

# %% [markdown]
# En general, si los datos están disponibles públicamente (el contenido que se está extrayendo no está detrás de un sistema de autenticación protegido por contraseña), entonces es legal extraerlos.
# Salvo que nuestra intención sea hacerlos pasar como datos de nuestra propiedad, copiarlos palabra por palabra o tratar de ganar dinero con ellos, es legal reutilizar el contenido disponible públicamente extraído de Internet.
# En cualquier caso si tienes dudas lo más sencillo es contactar al autor para pedirle permiso y citar la fuente de los datos.

# %% [markdown]
# ## HERRAMIENTAS PARA EL WEBSCRAPPING

# %% [markdown]
# Algunas de las más utilizadas son:
#
# #### BeautifulSoup:
# Es una biblioteca de Python que permite extraer datos de archivos HTML y XML. Proporciona métodos y funciones para analizar y manipular el contenido de una página web de manera sencilla.
#
# #### Scrapy:
# Es un framework de Python diseñado específicamente para el web scraping. Proporciona una estructura completa y flexible para escribir arañas (spiders) que pueden recorrer sitios web, extraer datos y seguir enlaces automáticamente.
#
# #### Selenium:
# Es una herramienta que permite la automatización de navegadores web. A través de Selenium, puedes controlar un navegador (como Chrome o Firefox) de manera programática, interactuar con elementos de la página web y extraer datos. Es útil cuando se necesita interactuar con sitios web dinámicos o que requieren autenticación.
#
# #### Puppeteer:
# Es una biblioteca de Node.js que proporciona un control de alto nivel sobre el navegador Chrome o Chromium a través de la API de DevTools Protocol. Permite realizar acciones automatizadas en el navegador, como hacer clic en elementos, completar formularios y extraer datos.
#
# #### Octoparse:
# Es una herramienta de web scraping visual que no requiere conocimientos de programación. Permite crear rutas de navegación en el sitio web y extraer datos mediante selecciones visuales. Es una buena opción para aquellos que no tienen experiencia en programación pero desean realizar web scraping.

# %% [markdown]
# <center> <h1> Desarrollo WebScraping </h1> </center>

# %% [markdown]
# ## <font color=#33A5FF>****Importamos las librerias para el Scriping****<tfont>

# %%
import bs4 as bs 
import requests
from tqdm import tqdm # Para ver cuanto demora la ejecucion del codigo
import pandas as pd

# %%
#Request para leer la dara sin cambiar informacion
web = requests.get("http://www.iris.washington.edu/latin_am/evlist.phtml?region=mundo")
tex = web.text #pasamos a texto
#convertimos a un objeto de beautifulsoup para trabajar com html de manera eficiente
#usamos 'lxml' para manejar html mas facilmente
soup = bs.BeautifulSoup(tex, "lxml") 
#buscamos una table con el nombre de la clase
tabla = soup.find("table",{"class":"tablesorter"})
tabla
# Out:
# <table cellspacing="1" class="tablesorter" id="evTable">
# <thead>
# <tr>
# <!-- for CSS tooltips I  show how to do it, but is awkward and risky and
#              complex if can avoid is good. -->
# <th title="Fecha y hora del terremoto, UTC explicado abajo">FECHA - HORA (UTC)<br/><div class="smallhead">día-mes-año hora:min:seg</div></th>
# <th class="latlon" title="Latitude en grados">LAT  <br/><div class="smallhead">grados</div></th>
# <th class="latlon" title="Longitude en grados">LON  <div class="smallhead">grados</div></th>
# <th class="mag" title="Magnitud, explicado abajo">MAG  <br/><div class="smallhead">explicado abajo</div></th>
# <th class="smallhead" title="Profundidad en kilometers bajo el nivel del mar">PROF<br/><div class="smallhead">km</div></th>
# <th class="region" title="Pulsa para un mapa de donde ocurrió">  LOCALIDAD  <div class="smallhead">  haga clic para ver mapa</div></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td> 22-JUN-2023 22:36:50 </td>
# ...

# %%
#creamos listas vacias 
columna_0 = []
columna_3 = []
columna_5 = []

#se crea un for para navegar por cada elemento y buscar los datos
for i in tqdm(tabla.findAll("tr")[1:]):
    dato_1 = i.findAll("td")[0].text
    dato_2 = i.findAll("td")[3].text
    dato_3 = i.findAll("td")[5].text
    #agregamos los datos a cada lista
    columna_0.append(dato_1)
    columna_3.append(dato_2)
    columna_5.append(dato_3)
# Out:
# 100%|██████████████████████████████████████| 100/100 [00:00<00:00, 14913.08it/s]

# %%
#visualizamos columna 5
columna_5
# Out:
# [' MINAHASSA PENINSULA, SULAWESI ',
#  ' ALASKA CENTRAL ',
#  ' REGIÓN DE LAS ISLAS KERMADAC ',
#  ' FRENTE A LA COSTA DE CENTROAMÉRICA ',
#  ' AL ESTE DE HONSHU, JAPóN ',
#  ' ISLAS VANUATU ',
#  ' SUR DE ISLAS DE TONGA ',
#  ' SUDESTE DE HONSHU, JAPóN ',
#  ' HOKKAIDO, JAPAN REGION ',
#  ' TANIMBAR ISLAS REG., INDONESIA ',
#  ' HOKKAIDO, JAPAN REGION ',
#  ' SUR DE ISLAS DE TONGA ',
#  ' TAIWÁN ',
#  ' SUR DE ISLAS DE TONGA ',
#  ' TURQUÍA ',
#  ' CRIMEA REGIÓN, UCRANIA ',
#  ' REGIÓN DE LAS ISLAS TONGA ',
#  ' ISLAS RYUKYU, JAPÓN ',
#  ' ISLAS SALOMÓN ',
#  ' CERCA LA COSTA SUR DE MYANMAR ',
#  ' ISLA DE ANDREANOF, ISLAS ALEUTIANAS ',
#  ' CERCA LA COSTA SUR DE MYANMAR ',
#  ' REGIÓN DE LAS ISLAS TONGA ',
#  ' ADRIÁTICO ',
#  ' ISLAS SUR DE SANDWICH REGIÓN ',
#  ' REGIÓN DE LAS ISLAS KERMADAC ',
#  ' ISLAS KURILES ',
#  ' AL SUR DE LAS ISLAS FIJI ',
#  ' REGIÓN DE LAS ISLAS KERMADAC ',
#  ' EL SUR DE IRáN ',
#  ' SUR DORSAL MEDIO-ATLANTICA ',
#  ' SUR DORSAL MEDIO-ATLANTICA ',
# ...

# %%
#pasamos nuestros datos a un dataframe
df = pd.DataFrame(list(zip(columna_0,columna_3,columna_5)),
                 columns=["Fecha/hora","Magnitud","Localidad"])
df.head(3)
# Out:
#                Fecha/hora Magnitud                        Localidad
# 0   22-JUN-2023 22:36:50      4.7    MINAHASSA PENINSULA, SULAWESI
# 1   22-JUN-2023 19:50:19      4.3                   ALASKA CENTRAL
# 2   22-JUN-2023 19:33:44      5.1     REGIÓN DE LAS ISLAS KERMADAC

# %%
#vemos la dimension
df.shape
# Out:
# (100, 3)

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fecha/hora  100 non-null    object
#  1   Magnitud    100 non-null    object
#  2   Localidad   100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %% [markdown]
# #### Tenemos que arreglar magnitud y la fecha

# %%
#convertimos magnitud de object a float
#convertimos Fecha/hora a un datetime
df["Magnitud"] = df["Magnitud"].astype(float)
df["Fecha/hora"] = pd.to_datetime(df["Fecha/hora"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fecha/hora  100 non-null    datetime64[ns]
#  1   Magnitud    100 non-null    float64
#  2   Localidad   100 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 2.5+ KB

# %%
#visuaizamos el dataframe arreglado
data_arreglo = df.set_index("Fecha/hora")
data_arreglo.head()
# Out:
#                      Magnitud                             Localidad
# Fecha/hora
# 2023-06-22 22:36:50       4.7        MINAHASSA PENINSULA, SULAWESI
# 2023-06-22 19:50:19       4.3                       ALASKA CENTRAL
# 2023-06-22 19:33:44       5.1         REGIÓN DE LAS ISLAS KERMADAC
# 2023-06-22 19:27:56       4.9   FRENTE A LA COSTA DE CENTROAMÉRICA
# 2023-06-22 17:33:44       4.6             AL ESTE DE HONSHU, JAPóN

# %%
#visualizamos datos estadisticos
df.describe().T
# Out:
#           count   mean       std  min    25%  50%  75%  max
# Magnitud  100.0  4.784  0.459187  4.0  4.475  4.7  5.0  6.4

# %%
maximo_total = data_arreglo["Magnitud"].max()
df_maximo_total = data_arreglo[data_arreglo["Magnitud"] == maximo_total]
df_maximo_total.head()
# Out:
#                      Magnitud              Localidad
# Fecha/hora
# 2023-06-18 20:30:22       6.4   GOLFO DE CALIFORNIA

# %%
minimo_total = data_arreglo["Magnitud"].min()
df_minimo_total = data_arreglo[data_arreglo["Magnitud"] == minimo_total]
df_minimo_total.head()
# Out:
#                      Magnitud                   Localidad
# Fecha/hora
# 2023-06-22 13:50:50       4.0   SUDESTE DE HONSHU, JAPóN
# 2023-06-22 05:21:04       4.0                    TURQUÍA
# 2023-06-18 22:17:33       4.0                 TAYIKISTÁN

# %%
promedio = data_arreglo["Magnitud"].mean()
promedio
# Out:
# 4.783999999999999

# %%
#importamos matplotlib para graficar
import matplotlib.pyplot as plt

# %%
#Grafica tipo caja
plt.boxplot(data_arreglo["Magnitud"])
plt.show()

# %%
plt.scatter(x= data_arreglo["Localidad"], y=data_arreglo["Magnitud"])
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(5,10))
sns.countplot(y=data_arreglo["Localidad"])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Localidad'>

# %%
data_arreglo["Localidad"].value_counts().index
# Out:
# Index([' REGIÓN DE LAS ISLAS TONGA ',
#        ' CERCA LA COSTA N. DE NUEVA GUINEA, PNG. ',
#        ' CERCA LA COSTA SUR DE MYANMAR ', ' ISLAS KURILES ',
#        ' ISLAS FIJI REGIÓN ', ' REGIÓN DE LAS ISLAS KERMADAC ',
#        ' KYUSHU, JAPóN, ', ' SUR DE ISLAS DE TONGA ',
#        ' HOKKAIDO, JAPAN REGION ', ' TURQUÍA ',
#        ' SOUTHERN SUMATRA, INDONESIA ', ' MAR BANDA ',
#        ' EN EL NORTE DE CHILE ', ' GOLFO DE CALIFORNIA ',
#        ' SUR DORSAL MEDIO-ATLANTICA ', ' SUR DE MAR DE LAS MOLUCAS ',
#        ' MINDANAO, FILIPINAS ', ' FRENTE A LA COSTA DE CENTROAMÉRICA ',
#        ' AL ESTE DE HONSHU, JAPóN ', ' ISLAS VANUATU ',
#        ' CHILE-ARGENTINA FRONTERA REGIÓN ',
#        ' TAYIKISTÁN-XINJIANG REGIÓN FRONTERA ',
#        ' CERCA DE LA COSTA CENTRAL DE CHILE ', ' RUMANIA ',
#        ' HALMAHERA, INDONESIA ', ' COLORADO ', ' ISLAS MARIANA ',
#        ' TURQUÍA-IRAN FRONTERA REGIÓN ', ' REGIÓN DE LAS ISLAS FILIPINAS ',
# ...

# %%
plt.figure(figsize=(5,10))
sns.countplot(y=data_arreglo["Localidad"], order = data_arreglo["Localidad"].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Localidad'>

# %%
from funpymodeling.exploratory import freq_tbl
freq_tbl(data_arreglo.Localidad)
# Out:
#                                     Localidad  frequency  percentage  \
# 0                  REGIÓN DE LAS ISLAS TONGA          12        0.12
# 1    CERCA LA COSTA N. DE NUEVA GUINEA, PNG.           6        0.06
# 2              CERCA LA COSTA SUR DE MYANMAR           5        0.05
# 3                              ISLAS KURILES           4        0.04
# 4                          ISLAS FIJI REGIÓN           3        0.03
# 5               REGIÓN DE LAS ISLAS KERMADAC           3        0.03
# 6                             KYUSHU, JAPóN,           3        0.03
# 7                      SUR DE ISLAS DE TONGA           3        0.03
# 8                     HOKKAIDO, JAPAN REGION           3        0.03
# 9                                    TURQUÍA           3        0.03
# 10               SOUTHERN SUMATRA, INDONESIA           2        0.02
# 11                                 MAR BANDA           2        0.02
# 12                      EN EL NORTE DE CHILE           2        0.02
# ...

# %%
data_arreglo.plot()
plt.show()

# %%
df = data_arreglo.sort_values(by="Magnitud",ascending=[False]) 
df
# Out:
#                      Magnitud                                  Localidad
# Fecha/hora
# 2023-06-18 20:30:22       6.4                       GOLFO DE CALIFORNIA
# 2023-06-18 21:59:17       6.0                             SUR DE ÁFRICA
# 2023-06-19 11:18:11       5.9   CERCA LA COSTA N. DE NUEVA GUINEA, PNG.
# 2023-06-18 15:04:49       5.8                 REGIÓN DE LAS ISLAS TONGA
# 2023-06-20 19:59:16       5.7                         ISLAS FIJI REGIÓN
# ...                       ...                                        ...
# 2023-06-19 04:19:01       4.1       TAYIKISTÁN-XINJIANG REGIÓN FRONTERA
# 2023-06-19 22:45:00       4.1                                   RUMANIA
# 2023-06-22 05:21:04       4.0                                   TURQUÍA
# 2023-06-22 13:50:50       4.0                  SUDESTE DE HONSHU, JAPóN
# 2023-06-18 22:17:33       4.0                                TAYIKISTÁN
#
# [100 rows x 2 columns]

# %%
solo_10 = df.iloc[0:10,0:2]
solo_10


plt.figure(figsize=(14,14))
plt.xticks(rotation=45, ha='right')
plt.bar(solo_10["Localidad"], solo_10["Magnitud"], )
plt.show()

# %%
data_arreglo.to_csv('Magnitud.csv', index=False)

# %% [markdown]
# ![linea 1](https://user-images.githubusercontent.com/19308295/115926252-2b8a0c00-a448-11eb-9d9c-b43beaf0ff68.png)

# %% [markdown]
# ## <font color=#33A5FF>****BIBLIOGRAFÍA****<tfont>

# %% [markdown]
# [1] Automate the Boring Stuff with Python  https://automatetheboringstuff.com/
#
# [2] BeautifulSoup https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# [3] Scrapy https://docs.scrapy.org/en/latest/
#
# [4] Selenium https://www.selenium.dev/documentation/
#
# [5] Puppeteer https://pptr.dev/
#
# [6] Web Scrapping para la obtencion de datos actualizada en internet https://repositorio.umsa.bo/handle/123456789/8405
